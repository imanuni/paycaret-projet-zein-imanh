# %% [markdown]
# <a href="https://colab.research.google.com/github/imanuni/paycaret-projet-zein-imanh/blob/main/projetPycaret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 79.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 73.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 20.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 70.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.7 MB/s eta 0:00:00
# ...

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('titanic')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
from pycaret.classification import *

# %%
s=setup(df,target='class')
# Out:
# <style type="text/css">
# #T_723cd_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_723cd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_723cd_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_723cd_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_723cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_723cd_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_723cd_row0_col1" class="data row0 col1" >7773</td>
#     </tr>
#     <tr>
#       <th id="T_723cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_723cd_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_723cd_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_723cd_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
nom_colonne = 'class'
nombre_valeurs_manquantes = df['class'].isna().sum()
print(f"Nombre de valeurs manquantes dans la colonne '{nom_colonne}': {nombre_valeurs_manquantes}")
# Out:
# Nombre de valeurs manquantes dans la colonne 'class': 0

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_f3701 th {
#   text-align: left;
# }
# ...

# %%
#j'ai choisi un autre data set

# %%
df=sns.load_dataset('taxis')

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
from pycaret.classification import *

# %%
print(df['distance'])
# Out:
# 0        1.60
# 1        0.79
# 2        1.37
# 3        7.70
# 4        2.16
#         ...
# 6428     0.75
# 6429    18.74
# 6430     4.14
# 6431     1.12
# 6432     3.85
# Name: distance, Length: 6433, dtype: float64

# %%
nom_colonne = ['distance','tip','fare']
nombre_valeurs_manquantes = df[['distance','tip','fare']].isna().sum()
print(f"Nombre de valeurs manquantes dans la colonne '{nom_colonne}': {nombre_valeurs_manquantes}")
# Out:
# Nombre de valeurs manquantes dans la colonne '['distance', 'tip', 'fare']': distance    0
# tip         0
# fare        0
# dtype: int64

# %%
manquantes=df[df['payment'].isna()]
manquantes
# Out:
#                   pickup             dropoff  passengers  distance  fare  tip  \
# 7    2019-03-22 12:47:13 2019-03-22 12:58:17           0       1.4   8.5  0.0
# 445  2019-03-19 06:57:14 2019-03-19 07:00:08           1       1.3   5.5  0.0
# 491  2019-03-07 07:11:33 2019-03-07 07:11:39           1       1.6   2.5  0.0
# 545  2019-03-27 11:03:43 2019-03-27 11:14:34           1       4.2  15.0  0.0
# 621  2019-03-15 17:16:35 2019-03-15 17:25:01           1       1.3   7.5  0.0
# 770  2019-03-02 03:16:59 2019-03-02 03:17:06           0       9.4   2.5  0.0
# 913  2019-03-23 11:26:58 2019-03-23 11:35:17           2       1.3   7.5  0.0
# 953  2019-03-08 02:58:37 2019-03-08 03:19:27           2       6.9  23.5  0.0
# 1207 2019-03-08 15:41:20 2019-03-08 15:41:23           1       0.0   2.5  0.0
# 1372 2019-03-12 09:19:44 2019-03-12 09:43:09           1       1.6  14.5  0.0
# 1566 2019-03-18 02:20:59 2019-03-18 02:49:24           1       6.0  23.0  0.0
# ...

# %%
df = df.dropna(subset=['payment'])
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
x = df[['fare','tip']]
x
# Out:
#       fare   tip
# 0      7.0  2.15
# 1      5.0  0.00
# 2      7.5  2.36
# 3     27.0  6.15
# 4      9.0  1.10
# ...    ...   ...
# 6428   4.5  1.06
# 6429  58.0  0.00
# 6430  16.0  0.00
# 6431   6.0  0.00
# 6432  15.0  3.36
#
# [6389 rows x 2 columns]

# %%
y=df['distance']
y
# Out:
# 0        1.60
# 1        0.79
# 2        1.37
# 3        7.70
# 4        2.16
#         ...
# 6428     0.75
# 6429    18.74
# 6430     4.14
# 6431     1.12
# 6432     3.85
# Name: distance, Length: 6389, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from pycaret.regression import *

# %%
models_to_include = ['lr', 'knn', 'rf', 'xgboost', 'nb','rfc']
s = setup(df, target='distance')
# Out:
# <style type="text/css">
# #T_0f58f_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0f58f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f58f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0f58f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f58f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f58f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0f58f_row0_col1" class="data row0 col1" >2000</td>
#     </tr>
#     <tr>
#       <th id="T_0f58f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f58f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0f58f_row1_col1" class="data row1 col1" >distance</td>
#     </tr>
#     <tr>
#       <th id="T_0f58f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model=compare_models()
# Out:
# <style type="text/css">
# #T_2e8dd th {
#   text-align: left;
# }
# ...

# %%
# Créez et évaluez le modèle Extra Trees Regression
et_model = create_model('et')
# Out:
# <style type="text/css">
# #T_bbe3b_row10_col0, #T_bbe3b_row10_col1, #T_bbe3b_row10_col2, #T_bbe3b_row10_col3, #T_bbe3b_row10_col4, #T_bbe3b_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_bbe3b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bbe3b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bbe3b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bbe3b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bbe3b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bbe3b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_bbe3b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...
